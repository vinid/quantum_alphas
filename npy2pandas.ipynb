# %%
import numpy as np
import os
import pandas as pd
import itertools

# %%
#file = np.load('3000dataset_alpha0.5.npy', allow_pickle = 'True')
#file2 = np.load('3000dataset_alpha0.6.npy', allow_pickle = 'True')

# %%
n = []
for root, dirs, files in os.walk("..", topdown=True):
    
    for name in files:
        n.append(name)
n[:]
# Out:
# ['color_noise-1qubit-(0.5-1.6)alphas-(0.98-2.18)random_tau-1Nf.csv',
#  'color_noise-1qubit-(0.6-2.0)alphas-1.58tau.csv',
#  'color_noise-1qubit-(0.8,0.9,1.0,1.1)alphas-1.57tau.csv',
#  'color_noise-2qubits-(0.6-2.0)alphas-1.58tau.csv',
#  '.gitattributes',
#  '.gitignore',
#  '3000original_dm.npy',
#  'colnoisedephasingterm.py',
#  'dataset_np2pandas.py',
#  'debug.log',
#  'little test.ipynb',
#  'L_list.npy',
#  'main.py',
#  'measurement_channel_generation.py',
#  'purestatesgeneration.py',
#  'README.md',
#  'sampling_couples_generation.py',
#  't0-1000tropicals-dm.npy',
#  't0-500-abovetropicals-dm.npy',
#  'test.py',
#  'timezero_states_generation.py',
#  'time_sampler.ipynb',
#  't_sampled_main_generation.py',
#  'COMMIT_EDITMSG',
#  'config',
#  'description',
#  'FETCH_HEAD',
#  'HEAD',
#  'index',
#  'packed-refs',
#  'applypatch-msg.sample',
#  'commit-msg.sample',
#  'fsmonitor-watchman.sample',
#  'post-update.sample',
#  'pre-applypatch.sample',
#  'pre-commit.sample',
#  'pre-merge-commit.sample',
#  'pre-push.sample',
#  'pre-rebase.sample',
#  'pre-receive.sample',
#  'prepare-commit-msg.sample',
#  'update.sample',
#  'exclude',
#  'HEAD',
#  'master',
#  'optimizing_colored_noise',
#  'HEAD',
#  'optimizing_colored_noise',
#  'a25f48ec17cd450b2b8271bf4f0c9f5d0e82a5',
#  '18cab7b6be27e3573eee11d3b7ee97138f6527',
#  '59b4ffdcc69ca01e197a9318d845ae82e1b98c',
#  '80a89b1180cd7da2a6dda86a0bb6a8ce4b693c',
#  '18dc54261a34a3bfdf31f393b625267b1f8c8d',
#  '84b15a9ec7e919423e01e39a66f16172398363',
#  'a2ef5518660ba528e55d8a00196a7b791189ca',
#  '7c1bb8587205a2bcc24f59a5bc9e4c20f33210',
#  'f5cd57b36da1d672be4bc40a6e08ab2e3aeaf6',
#  '6f8e805082ccfbc8f6cb8cecc8bd058a949de4',
#  '7bfce0b217e01ca499c4fbaa20e6b99a3bb759',
#  '61a3602a4feed81c609ffa46502a083199528b',
#  '4d734de36885eb4effc3b209aa192922277d50',
#  '2e011d1e2e2c279ff79560ff2f9358a0baf7de',
#  '7ff56cab31f46d5a51cee30cfa92a776c2eccf',
#  '1cffcb116bb924fdd11d937130195c7edfcb3d',
#  '9bac93c31e787930932c4ea5edc916d4c193d8',
#  'ffac943e6ef1eeca3db0a5a6244b369ec537e1',
#  '4d035bf5f589455a0462973159ed9d3337baf4',
#  'a0b3ef648af93612d974576d7d279f7aa685da',
#  'b92f00348906df85c490868440e78142f09154',
#  'ccd430185dac6d6c600bd1513ea7753dfa4615',
#  'e95098b5ce5a926fe9edbfdf782f27939711f6',
#  'little test-checkpoint.ipynb',
#  'time_sampler-checkpoint.ipynb',
#  'all-alpha-500test-for-tropical.csv',
#  'npy2pandas.ipynb',
#  't0-1000tropicals-dm.npy_alpha0.5.npy',
#  't0-1000tropicals-dm.npy_alpha0.6.npy',
#  't0-1000tropicals-dm.npy_alpha0.7.npy',
#  't0-1000tropicals-dm.npy_alpha0.8.npy',
#  't0-1000tropicals-dm.npy_alpha0.9.npy',
#  't0-1000tropicals-dm.npy_alpha1.0.npy',
#  't0-1000tropicals-dm.npy_alpha1.1.npy',
#  't0-1000tropicals-dm.npy_alpha1.2.npy',
#  't0-1000tropicals-dm.npy_alpha1.3.npy',
#  't0-1000tropicals-dm.npy_alpha1.4.npy',
#  't0-1000tropicals-dm.npy_alpha1.5.npy',
#  't0-1000tropicals-dm.npy_alpha1.6.npy',
#  't0-1000tropicals-dm.npy_alpha1.7.npy',
#  't0-1000tropicals-dm.npy_alpha1.8.npy',
#  't0-1000tropicals-dm.npy_alpha1.9.npy',
#  't0-1000tropicals-dm.npy_alpha2.0.npy',
#  't0-500-abovetropicals-dm.npy_alpha0.5.npy',
#  't0-500-abovetropicals-dm.npy_alpha0.6.npy',
#  't0-500-abovetropicals-dm.npy_alpha0.7.npy',
#  't0-500-abovetropicals-dm.npy_alpha0.8.npy',
#  't0-500-abovetropicals-dm.npy_alpha0.9.npy',
#  't0-500-abovetropicals-dm.npy_alpha1.0.npy',
#  't0-500-abovetropicals-dm.npy_alpha1.1.npy',
#  't0-500-abovetropicals-dm.npy_alpha1.2.npy',
#  't0-500-abovetropicals-dm.npy_alpha1.3.npy',
#  't0-500-abovetropicals-dm.npy_alpha1.4.npy',
#  't0-500-abovetropicals-dm.npy_alpha1.5.npy',
#  't0-500-abovetropicals-dm.npy_alpha1.6.npy',
#  't0-500-abovetropicals-dm.npy_alpha1.7.npy',
#  't0-500-abovetropicals-dm.npy_alpha1.8.npy',
#  't0-500-abovetropicals-dm.npy_alpha1.9.npy',
#  't0-500-abovetropicals-dm.npy_alpha2.0.npy',
#  'traintropical1000allalpha.csv',
#  'Untitled.ipynb',
#  'npy2pandas-checkpoint.ipynb',
#  'Untitled-checkpoint.ipynb',
#  '3000dataset_alpha0.5.npy',
#  '3000dataset_alpha0.6.npy',
#  '3000dataset_alpha0.7.npy',
#  '3000dataset_alpha0.8.npy',
#  '3000dataset_alpha0.9.npy',
#  '3000dataset_alpha1.0.npy',
#  '3000dataset_alpha1.1.npy',
#  '3000dataset_alpha1.2.npy',
#  '3000dataset_alpha1.3.npy',
#  '3000dataset_alpha1.4.npy',
#  '3000dataset_alpha1.5.npy',
#  '3000dataset_alpha1.6.npy',
#  '3000dataset_alpha1.7.npy',
#  '3000dataset_alpha1.8.npy',
#  '3000dataset_alpha1.9.npy',
#  '3000dataset_alpha2.0.npy',
#  'alltrain.csv',
#  'alltrainbeta.csv',
#  'dask-upload.ipynb',
#  'npy2pandas.ipynb',
#  'dask-upload-checkpoint.ipynb',
#  'npy2pandas-checkpoint.ipynb',
#  'train05.csv',
#  'train06.csv',
#  'alpha 17 to 2.pdf',
#  'colored_noise_optimized.ipynb',
#  'colored_noise_optimized-checkpoint.ipynb',
#  'boson_bath_dm_label0.1.npy',
#  'boson_bath_dm_label0.7.npy',
#  'boson_bath_dm_label1.5.npy',
#  'boson_bath_dm_label1.npy',
#  'boson_bath_dm_label2.5.npy',
#  'boson_bath_dm_label2.npy',
#  'boson_bath_dm_label3.npy',
#  'npy2pandas.ipynb',
#  'train-tropical-1000states-allalphas.csv',
#  'Untitled.ipynb',
#  'npy2pandas-checkpoint.ipynb',
#  'boson_L_list_alpha-0.1.npy',
#  'boson_L_list_alpha-0.7.npy',
#  'boson_L_list_alpha-1.5.npy',
#  'boson_L_list_alpha-1.npy',
#  'boson_L_list_alpha-2.5.npy',
#  'boson_L_list_alpha-2.npy',
#  'boson_L_list_alpha-3.npy',
#  'rand-times.jpg',
#  '1q-haar-puresicborn-t1.58-alpha1.csv',
#  '1q-haar-puresicborn-t3.14-allalphas.csv',
#  '3000-filtered-states.csv',
#  'adri-noisesicborn-t1.58-allalphas.csv',
#  'adri-noisesicborn-t3.14-allalphas.csv',
#  'ansatz.pickle',
#  'atest.csv',
#  'test-noisesicborn-t1.58-alpha1.csv',
#  'test.pickle',
#  'time314.csv',
#  'Untitled.ipynb',
#  'Untitled-checkpoint.ipynb',
#  '2000tropicals-dm.npy',
#  'all_alphas_Nf1.pdf',
#  'all_alphas_Nf1.png',
#  'all_alphas_Nf11.pdf',
#  'bose_bath_plot.ipynb',
#  'colored_noise_optimized.ipynb',
#  's0.1-0.4.pdf',
#  's0.1-3.5wc1.5.jpg',
#  's0.5-2.8.pdf',
#  'stem.pdf',
#  'stem.png',
#  'bose_bath_plot-checkpoint.ipynb',
#  'colored_noise_optimized-checkpoint.ipynb',
#  'L_list_alpha-0.5.npy',
#  'L_list_alpha-0.6.npy',
#  'L_list_alpha-0.7.npy',
#  'L_list_alpha-0.8.npy',
#  'L_list_alpha-0.9.npy',
#  'L_list_alpha-1.0.npy',
#  'L_list_alpha-1.1.npy',
#  'L_list_alpha-1.2.npy',
#  'L_list_alpha-1.3.npy',
#  'L_list_alpha-1.4.npy',
#  'L_list_alpha-1.5.npy',
#  'L_list_alpha-1.6.npy',
#  'L_list_alpha-1.7.npy',
#  'L_list_alpha-1.8.npy',
#  'L_list_alpha-1.9.npy',
#  'L_list_alpha-2.0.npy',
#  'colnoisedephasingterm.cpython-38.pyc',
#  'measurement_channel_generation.cpython-36.pyc',
#  'measurement_channel_generation.cpython-38.pyc',
#  'measurement_generation.cpython-38.pyc',
#  'purestatesgeneration.cpython-37.pyc',
#  'purestatesgeneration.cpython-38.pyc',
#  '.gitignore',
#  'debug.log',
#  'README.md',
#  'COMMIT_EDITMSG',
#  'config',
#  'description',
#  'FETCH_HEAD',
#  'HEAD',
#  'index',
#  'ORIG_HEAD',
#  'packed-refs',
#  'applypatch-msg.sample',
#  'commit-msg.sample',
#  'fsmonitor-watchman.sample',
#  'post-update.sample',
#  'pre-applypatch.sample',
#  'pre-commit.sample',
#  'pre-merge-commit.sample',
#  'pre-push.sample',
#  'pre-rebase.sample',
#  'pre-receive.sample',
#  'prepare-commit-msg.sample',
#  'update.sample',
#  'exclude',
#  'HEAD',
#  'master',
#  'HEAD',
#  'master',
#  '274ea61383911d8c3a2afdd8c3848135c1fa68',
#  '8074ac8b462a710e0a7d8811c6e2576a355b06',
#  'cfcea3ffd6fd74bb0d42c3f8bc4726102431c5',
#  'b4d9f19298dba097dbd08ee7c0f16a31c241aa',
#  'be375e9f64cf0e52c8d7b0a91d5feaeb032077',
#  '728b092d61f213fe1af2a66299955d47363937',
#  'a92bef7ad17cb4f90ea7fdc934d66d61ff2585',
#  'dc40408ec7fd510482fa2752b91012d549f1af',
#  '4bfa30f02e9fecaa5bb4c8e4f3eb110160cb54',
#  'a68010780d3295f4f664d40132b6ae3f694bce',
#  'c9e0adc200265ae38f8c7db0b21abad631efc4',
#  '6aafffc0bb327df67abb8e8842e7f40431fa12',
#  '9c2978753c6378667645ba7502fd2440d6c935',
#  '703dc9995591d197200d819d6e451b97956a09',
#  'a321bd3f567a442433184760212a935e0d4993',
#  '41be4e68c0b6f5cd0c8bda7c4c1b9d4d3cbc6c',
#  '38f7ccc6181f7627c8aeb5c56af6533259da1e',
#  'e820bb3c8b03f872b570caca377901046c93c3',
#  '0bf928f865ad171885a6914baecce8ece86436',
#  'd920171f145abd7dd4183f7ae0360d1bccbebe',
#  '852aa767697130dd27d6fb60d2d51110e5ffb1',
#  '9950b65a44b06488ae0df81570638e597ebfe1',
#  'fe315563ea8df802c175eb34a39b58163a7007',
#  '072af0e820e60c9b1ac514219d90f3bcdf8eaa',
#  'b586b57388b1362a3e9efb1927acd1882da100',
#  '84bcf2f01327e47dc59933a54d98e760c7f476',
#  '741746460d8699dd6e2a0df693f2e185032459',
#  'b286fdc0b95d2d56d42d63242d480ef42f03e7',
#  '64e119965eb4c987dda7d197db294a8498a359',
#  '024a715a20504c90d8946b3eef9e9d160b7b1c',
#  '2775f6e32e734d219a9595f1f6acf52de68cd5',
#  '231458d4ae5f9b48d279ed17bd9c38c5bd1f79',
#  '7fbce8e0069a54cd424685bccb245dbe4b74b9',
#  'ab84d07a96c1a51cedbc3e565513a4aacd7282',
#  '1a8f8e8887e3ad41855e198c9ad0b8daea4326',
#  '26159cc7e1f0208212f4fae531cc3db16c7b9d',
#  'b2c54bd11efbc1cc7d7a747ae6c857a8842628',
#  'c1bc5589cfd382d8a3222596718edc1d8d17af',
#  '968a10bcf24c5e034c87954373595d761983eb',
#  '1ea10eda0492166a7c4c878bb679b4a0f4ce1e',
#  '872e917a8e01091ebf04c241842380a538bca3',
#  '71ec4cb95fba640d8d136e6ed1342f3490ae06',
#  '6b1a7184a42e8eed035c42816d989d023c932d',
#  '783972931159649d33a9160d20282641fb309d',
#  'df7696a9484e0d57f7a54c6c4e50c2bf959b6c',
#  '0c0f806b7e33ab40c604751c8c9376f0f64724',
#  'a3f8e4e25089a4ee5dcc7949bbfb5398adf936',
#  '7b8b9c7a7db361d48f7267a472ef6c2cfd97fc',
#  'f21e3815bf9e1d09b6d06df73339aa31d226c1',
#  '7dae848a7064b1e98c365de767135ec68b2617',
#  '74d07493ddb95d76ec75f71dd0421cf4b15b67',
#  '17cb2faf5f6b43a6433beed8469320646f8aac',
#  'pack-7e6f76a083d100fe22323b176d99c5b853e94375.idx',
#  'pack-7e6f76a083d100fe22323b176d99c5b853e94375.pack',
#  'master',
#  'HEAD',
#  'master',
#  'regression.ipynb',
#  'regression-checkpoint.ipynb',
#  '2.0VSall_pred.txt',
#  'classification.ipynb',
#  'copycolor_noise-1qubit-(0-.6-2.0)alphas-(1.54-1.62)random_tau.csv',
#  'debug.log',
#  'pureVSall_pred.txt',
#  'Untitled.ipynb',
#  'classification-checkpoint.ipynb',
#  'Untitled-checkpoint.ipynb',
#  'color_noise-1qubit-(0.5-1.5)alphas-(1.54-1.62)random_tau-7Nf.csv',
#  'conv1d_model.py',
#  'copycolor_noise-1qubit-(0-.6-2.0)alphas-(1.54-1.62)random_tau.csv',
#  'debug.log',
#  'mutli class.ipynb',
#  'softmax-cce-model_0.6-1.5_alphas.json',
#  'softmax-cce-model_0.6-1.6plusmix1.7-2.json',
#  'softmax-cce-model_1.7-2.0_alphas.json',
#  'softmax-cce-model_all_alphas.json',
#  'softmax-model_0.6-1.5_alphas.json',
#  'mutli class-checkpoint.ipynb',
#  'color_noise-1qubit-(0.6-2.0)alphas-(1.54-1.62)random_tau.csv',
#  'color_noise-1qubit-(1.6-2.0)alphas-(1.54-1.62)random_tau-51Nf.csv',
#  'copycolor_noise-1qubit-(0-.6-2.0)alphas-(1.54-1.62)random_tau.csv',
#  'model.json',
#  'multilabel-classifier.py',
#  'model.json',
#  'model_0.6-1.5vs2_alphas',
#  'THEREALmodel_0.6-1.5vs2_alphas.json',
#  'classification_report_sigmoid.csv',
#  'classification_report_sigmoid_Es15.csv',
#  'classification_report_sigmoid_Es15_20_0.6-1.5_Nf7.csv',
#  'classification_report_sigmoid_Es_20_1.7-2_Nf51.csv',
#  'classification_report_softmax.csv',
#  'softmax cce_1.7-2_Nf51.csv',
#  'softmax_cce-report0.6-1.6plusmix1.7-2.csv',
#  'softmax_cce-reports0.6-1.5alphas.csv',
#  'softmax_cce-reports1.7-2.0alphas.csv',
#  'softmax_cce-reportsallalphas.csv',
#  'softmax_reports0.6-1.5alphas.csv',
#  '.gitignore',
#  'classifier_training.py',
#  'data.py',
#  'early_stopping.py',
#  'functions.py',
#  'models.py',
#  'training.csv',
#  'training.py',
#  'utils.py',
#  'misc.xml',
#  'modules.xml',
#  'quantum-gan.iml',
#  'vcs.xml',
#  'workspace.xml',
#  'profiles_settings.xml',
#  'data_generator.ipynb',
#  'extract_data.py',
#  'data_generator-checkpoint.ipynb',
#  'functions.py',
#  'support.py',
#  '__init__.py',
#  'data.cpython-37.pyc',
#  'data.cpython-38.pyc',
#  'functions.cpython-37.pyc',
#  'models.cpython-37.pyc',
#  'README.md',
#  'config',
#  'description',
#  'FETCH_HEAD',
#  'HEAD',
#  'index',
#  'packed-refs',
#  'applypatch-msg.sample',
#  'commit-msg.sample',
#  'fsmonitor-watchman.sample',
#  'post-update.sample',
#  'pre-applypatch.sample',
#  'pre-commit.sample',
#  'pre-merge-commit.sample',
#  'pre-push.sample',
#  'pre-rebase.sample',
#  'pre-receive.sample',
#  'prepare-commit-msg.sample',
#  'update.sample',
#  'exclude',
#  'HEAD',
#  'master',
#  'HEAD',
#  'pack-73c11c587bcd3fda381fd58845d9d6c2128f190a.idx',
#  'pack-73c11c587bcd3fda381fd58845d9d6c2128f190a.pack',
#  'master',
#  'HEAD',
#  'npy2pandas-checkpoint.ipynb',
#  'config.ini',
#  'training_baseline.py',
#  'training_transformer.py',
#  '__init__.py',
#  '3000bose.pkl',
#  'npy2pandas.ipynb',
#  'models.py',
#  'support_layers.py',
#  '__init__.py']

# %%
test = np.load('boson_bath_dm_label0.7.npy', allow_pickle = True)

# %%
m =n[:-3]

# %%
for i in range(len(m)): print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
#it takes one npy files p and convert it into a list of list
def explode(l):
    pp2 = list(itertools.chain.from_iterable(l[:2]))
    pp2.append(l[2])
    pp2.append(l[3])
    return pp2

#a = list(map(explode,p))

# %%
numfiles = 19
myfiles = {i : list(map(explode,np.load(m[i], allow_pickle=True))) for i in range(len(m))  }

# %%
dframes = [pd.DataFrame(myfiles[i]) for i in range(len(m))]

del(myfiles)

# %%
#for i in range(17): print(dframes[i].shape)

# %%
col_name1 = ['in_prob'+str(i) for i in range(1,5)]
col_name2 = ['fin_prob'+str(i) for i in range(1,5)]

for el in col_name2:col_name1.append(el)
col_name1.append('L_in')
col_name1.append('L_fin')

# %%
from itertools import repeat

datasetlen = 3000000
s = [0.1,0.7,1.5,1,2.5,2,3]
bose = list(itertools.chain(*[ list(repeat(step,datasetlen)) for step in  s ]))

# %%
col_name1 + ['label']
# Out:
# ['in_prob1',
#  'in_prob2',
#  'in_prob3',
#  'in_prob4',
#  'fin_prob1',
#  'fin_prob2',
#  'fin_prob3',
#  'fin_prob4',
#  'L_in',
#  'L_fin',
#  'label']

# %%
final = pd.concat(dframes,ignore_index = True)
final['label'] = bose
#final.to_pickle('3000bose.pkl',header =col_name1+ ['label'])
# Out:
# <bound method NDFrame.head of                  0         1         2         3         4         5  \
# 0         0.199940  0.131958  0.272290  0.395812  0.199940  0.187040
# 1         0.199940  0.137332  0.272067  0.390661  0.199940  0.187040
# 2         0.199940  0.137437  0.272062  0.390561  0.199940  0.187040
# 3         0.199940  0.140101  0.271952  0.388007  0.199940  0.187040
# 4         0.199940  0.143901  0.271793  0.384365  0.199940  0.187040
# ...            ...       ...       ...       ...       ...       ...
# 20999995  0.392156  0.212193  0.257945  0.137706  0.392156  0.212209
# 20999996  0.392156  0.212193  0.257945  0.137706  0.392156  0.212211
# 20999997  0.392156  0.212193  0.257945  0.137706  0.392156  0.212212
# 20999998  0.392156  0.212193  0.257945  0.137706  0.392156  0.212217
# 20999999  0.392156  0.212193  0.257945  0.137706  0.392156  0.212219
#
#                  6         7         8         9  label
# 0         0.269999  0.343021  0.660113  0.390235    0.1
# 1         0.269999  0.343021  0.633785  0.390235    0.1
# 2         0.269999  0.343021  0.633270  0.390235    0.1
# 3         0.269999  0.343021  0.620215  0.390235    0.1
# 4         0.269999  0.343021  0.601596  0.390235    0.1
# ...            ...       ...       ...       ...    ...
# 20999995  0.258035  0.137600  0.361434  0.362022    3.0
# 20999996  0.258048  0.137585  0.361434  0.362106    3.0
# 20999997  0.258056  0.137576  0.361434  0.362158    3.0
# 20999998  0.258083  0.137543  0.361434  0.362338    3.0
# 20999999  0.258092  0.137533  0.361434  0.362398    3.0
#
# [21000000 rows x 11 columns]>

# %%
final.columns = col_name1 + ['label']

# %%
final.to_pickle('3000bose.pkl')

# %%
bla = pd.read_pickle('3000bose.pkl')

# %%
l = bla.loc[0]

# %%
type(l[0])
# Out:
# numpy.float64
